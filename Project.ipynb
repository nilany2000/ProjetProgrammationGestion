# %%
#Import de la librairie pandas
import pandas

#Lecture des fichiers de données en spécifiant le séparateur point-virgule ';'
equipeJO = pandas.read_csv("20162020_JO_Team.csv", sep=';')
joueurJO2016 = pandas.read_csv("2016_JO_Player.csv", sep=';')
joueurNBA2016 = pandas.read_csv("2016_NBA_Player.csv", sep=';')
joueurNBAWP2016 = pandas.read_csv("2016_NBA_Player_WP.csv", sep=';')
equipeNBA2016 = pandas.read_csv("2016_NBA_Team.csv", sep=';')
joueurJO2020 = pandas.read_csv("2020_JO_Player.csv", sep=';')
joueurNBA2020 = pandas.read_csv("2020_NBA_Player.csv", sep=';')
equipeNBA2020 = pandas.read_csv("2020_NBA_Team.csv", sep=';')

#print(notes.dtypes)
joueurJO2020
# Out:
#                Name  Age                    Team Position  Games Played  \
# 0      Kevin Durant   33           Brooklyn Nets        F             6
# 1      Jayson Tatum   24          Boston Celtics        F             6
# 2      Jrue Holiday   31         Milwaukee Bucks        G             6
# 3    Damian Lillard   31  Portland Trail Blazers        G             6
# 4       Zach LaVine   27           Chicago Bulls        G             6
# 5      Devin Booker   25            Phoenix Suns        G             6
# 6       Bam Adebayo   24              Miami Heat      F/C             6
# 7      JaVale McGee   34          Denver Nuggets        C             4
# 8   Khris Middleton   30         Milwaukee Bucks        F             6
# 9    Draymond Green   32   Golden State Warriors        F             6
# 10     Jerami Grant   28         Detroit Pistons        F             4
# 11   Keldon Johnson   22       San Antonio Spurs        G             4
#
#     Game Started  Field Goals Made   Field Goals Attempted  \
# 0              6                45                      85
# 1              0                33                      67
# 2              5                28                      58
# 3              6                23                      60
# 4              1                21                      35
# 5              5                19                      45
# 6              6                16                      28
# 7              0                10                      13
# 8              0                14                      31
# 9              1                 7                       9
# 10             0                 1                       3
# 11             0                 1                       3
#
#     Field Goals Made Percentage  3 Point Made  ...  Total Rebounds  \
# 0                          0.52            15  ...              32
# 1                          0.49            17  ...              20
# 2                          0.48             7  ...              29
# 3                          0.38            16  ...              16
# 4                          0.60            10  ...              12
# 5                          0.42             5  ...              19
# 6                          0.57             0  ...              34
# 7                          0.76             0  ...               5
# 8                          0.45             6  ...              11
# 9                          0.77             3  ...              18
# 10                         0.33             3  ...               5
# 11                         0.33             1  ...               3
#
#     Rebounds Average  Total Points  Points Average  Total Assists  \
# 0                5.3           124            20.7             22
# 1                3.3            91            15.2              7
# 2                4.8            71            11.8             23
# 3                2.7            67            11.2             19
# 4                2.0            58             9.7             20
# 5                3.4            56             9.3             11
# 6                5.7            38             6.3             11
# 7                1.3            25             6.3              0
# 8                1.8            35             5.8             10
# 9                3.0            21             3.5             17
# 10               1.3             4             1.0              3
# 11               0.8             4             1.0              3
#
#     Assists Average  Total Blocks  Blocks Average  Steals  Steals Average
# 0              3.67             7            1.17       6            1.00
# 1              1.17             7            1.17       3            0.50
# 2              3.83             5            0.83      10            1.67
# 3              3.17             0            0.00       3            0.50
# 4              3.33             0            0.00       5            0.83
# 5              1.83             2            0.33       9            1.50
# 6              1.83             7            1.17       8            1.33
# 7              0.00             2            0.50       2            0.50
# 8              1.67             5            0.83       5            0.83
# 9              2.83             7            1.17       7            1.17
# 10             0.75             1            0.25       1            0.25
# 11             0.75             0            0.00       0            0.00
#
# [12 rows x 25 columns]

# %% [markdown]
# Quel est la corrélation entre la participation aux Olympiques et le classements des joueurs dans la NBA?

# %%
# jointure
#df_sales_full = df_sales.join(df_product.set_index("product_id"), on="product_id")

#print(joueurJO2016.columns)
joueur2016 = joueurJO2016.join(joueurNBA2016.set_index('Name'), on="Name", lsuffix='JO', rsuffix='NBA', how='inner')
joueur2020 = joueurJO2020.join(joueurNBA2020.set_index('Name'), on="Name", lsuffix='JO', rsuffix='NBA', how='inner')


#print(joueurJO2016.dtypes)
#print(joueurNBA2016.dtypes)
print(joueur2020.dtypes)
# Out:
# Name                                object
# AgeJO                                int64
# TeamJO                              object
# PositionJO                          object
# Games PlayedJO                       int64
# Game StartedJO                       int64
# Field Goals Made                     int64
#  Field Goals Attempted               int64
# Field Goals Made PercentageJO      float64
# 3 Point Made                         int64
# 3 Point Attempted                    int64
# 3 Point Made Percentage            float64
# Free Throws Made                     int64
# Free Throws Attempted                int64
# Free Throws Made PercentageJO      float64
# Total Rebounds                       int64
# Rebounds Average                   float64
# Total Points                         int64
# Points Average                     float64
# Total Assists                        int64
# Assists Average                    float64
# Total Blocks                         int64
# Blocks Average                     float64
# Steals                               int64
# Steals Average                     float64
# Rank                                 int64
# AgeNBA                             float64
# TeamNBA                            float64
# PositionNBA                        float64
# Games PlayedNBA                      int64
# Game StartedNBA                    float64
# Field Goals Made Per Game          float64
#  Field Goals Attempted Per Game    float64
# Field Goals Made PercentageNBA     float64
# 3 Point Made Per Game              float64
# 3 Point Attempted Per Game         float64
# 3 Point Made Percentage            float64
# Free Throws Made Per Game          float64
# Free Throws Attempted Per Game     float64
# Free Throws Made PercentageNBA     float64
# Rebounds Per Game                  float64
# Points Per game                    float64
# Assists per game                   float64
# Blocks per Game                    float64
# Steals Per Game                    float64
# dtype: object

# %% [markdown]
# Est-ce que les joueurs de la NBA ont une performance similaire moyenne en saison régulière comparé aux olympiques (Points, rebound, assist et block)?

# %% [markdown]
# Est-ce que la performance moyenne d'une équipe de la NBA est semblable à une équipe Olympique?

# %% [markdown]
# Est-ce que l'écart-type est similaire entre les joueurs d'une équipe de la NBA et ceux d'une équipe Olympique?

# %%
#L'ecart-type des joueurs de l'equipe NBA 2016
joueurNBA2016[["Points Per game","Rebounds Per Game","Assists per game","Blocks per Game"]]
NBA2016= joueurNBA2016.agg({"Points Per game": ["std"],
           "Rebounds Per Game": ["std"],
           "Assists per game":["std"],
           "Blocks per Game": ["std"]})
NBA2016
# Out:
#      Points Per game  Rebounds Per Game  Assists per game  Blocks per Game
# std         2.385808           3.096564          2.765744         0.540248

# %%
# L'écart-type des joueurs de l'équipe Olympique 2016
joueurJO2016[["Points Average","Rebounds Average","Assists Average","Average Blocks"]]
J02016= joueurJO2016.agg({"Points Average": ["std"],
           "Rebounds Average": ["std"],
           "Assists Average":["std"],
           "Average Blocks": ["std"]})
J02016
# Out:
#      Points Average  Rebounds Average  Assists Average  Average Blocks
# std        4.638639          1.672958         1.105494        0.259452

# %%
# L'écart-type des joueurs de l'équipe Olympique 2020
joueurJO2020
joueurJO2020[["Points Average","Rebounds Average","Assists Average","Blocks Average"]]
Jo2020= joueurJO2020.agg({"Points Average": ["std"],
           "Rebounds Average": ["std"],
           "Assists Average":["std"],
           "Blocks Average": ["std"]})
JO2020
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/xt/8_kml2fj42j6fgfg64btcjfr0000gn/T/ipykernel_8731/1083645602.py in <module>
#       6            "Assists Average":["std"],
#       7            "Blocks Average": ["std"]})
# ----> 8 JO2020
#
# NameError: name 'JO2020' is not defined

# %%
#L'écart-type des joueurs de l'equipe NBA 2020
joueurNBA2020[["Points Per game","Rebounds Per Game","Assists per game","Blocks per Game"]]
NBA2020= joueurNBA2020.agg({"Points Per game": ["std"],
           "Rebounds Per Game": ["std"],
           "Assists per game":["std"],
           "Blocks per Game": ["std"]})
NBA2020
# Out:
#      Points Per game  Rebounds Per Game  Assists per game  Blocks per Game
# std         2.596171           2.879012          1.860751         0.394168

# %%
df_tauxchange = pandas.concat([NBA2020,JO2020,JO2016,NBA2016])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/xt/8_kml2fj42j6fgfg64btcjfr0000gn/T/ipykernel_8731/1869139515.py in <module>
# ----> 1 df_tauxchange = pandas.concat([NBA2020,JO2020,JO2016,NBA2016])
#
# NameError: name 'pandas' is not defined
